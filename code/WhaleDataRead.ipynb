# %%
import pandas

WhaleData = pandas.read_csv("https://raw.githubusercontent.com/JSRist0028/animalmigration/main/data/Azores%20Great%20Whales%20Satellite%20Telemetry%20Program%20.csv")

WhaleData
# Out:
#         event-id  ...                                        study-name
# 0      679429032  ...  Azores Great Whales Satellite Telemetry Program
# 1      679429033  ...  Azores Great Whales Satellite Telemetry Program
# 2      679429034  ...  Azores Great Whales Satellite Telemetry Program
# 3      679429035  ...  Azores Great Whales Satellite Telemetry Program
# 4      679429036  ...  Azores Great Whales Satellite Telemetry Program
# ...          ...  ...                                               ...
# 6619  1711277114  ...  Azores Great Whales Satellite Telemetry Program
# 6620  1711277115  ...  Azores Great Whales Satellite Telemetry Program
# 6621  1711277116  ...  Azores Great Whales Satellite Telemetry Program
# 6622  1711277117  ...  Azores Great Whales Satellite Telemetry Program
# 6623  1711277118  ...  Azores Great Whales Satellite Telemetry Program
#
# [6624 rows x 35 columns]
